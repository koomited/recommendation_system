# %% [markdown]
# # Results on the 100K movilens datasets

# %%
from alternating_least_square import AlternatingLeastSquare
import matplotlib.pyplot as plt

# %% [markdown]
# # create object and get the data

# %%
data_dir = '../data/ml-latest-small/ratings.csv'
als_100k_data = AlternatingLeastSquare(data_dir, embedding_dim=20)

# %%
als_100k_data.data_indexing()

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Power law

# %%
als_100k_data.plot_power_law("power_law_100k")

# %% [markdown]
# ### Ratings distribution

# %%
als_100k_data.plot_average_rating_hist("Ratings_100k")

# %% [markdown]
# ## Train test split

# %%
als_100k_data.train_test_split()

# %% [markdown]
# ## Run the model: biases + embeddings

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= als_100k_data.alternating_least_square(als_100k_data.data_by_user_train, als_100k_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 100)
# Out:
# Training:  13%|████████▊                                                           | 13/100 [01:06<06:06,  4.21s/epoch, test_rmse=1.75]

# %% [markdown]
# ## Plot losses on training and test sets

# %%
als_100k_data.line_plot(losses, losses_test, xaxis = "Iterations" , yaxis= "LOSS", fig_name = "losses_100k")

# %% [markdown]
# ## On ly loss training

# %%
als_100k_data.plot_training_loss_only(losses,xaxis = "Iterations" , yaxis= "Loss", fig_name="loss_rain_100k")

# %% [markdown]
# ## Optimal values for lambda
# gamma = 0.001

# %%
losses_list =[]
lambdas=[0.01, 0.1, 1, 5]
for lambd in lambdas:
    _, _ ,losses_train, _, _, _= als_100k_data.alternating_least_square(als_100k_data.data_by_user_train, als_100k_data.data_by_movie_train, lambd=lambd, gamma=0.001, epochs =5)
    losses_list.append(losses_train)
# Out:
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.99s/epoch, test_rmse=1.01]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.91s/epoch, test_rmse=1.24]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.94s/epoch, test_rmse=1.57]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.93s/epoch, test_rmse=2.13]

# %%
def plot_trainings_losses(losses_list, lambdas=[0.01, 0.1, 1, 5]):

    fig, ax = plt.subplots(figsize=(8,5))
    colors= [ "blue", "green", "red", "purple"]
    for i in range(len(losses_list)):
      ax.plot(range(1,len(losses_list[i])+1), losses_list[i], 
              color=colors[i], ls='-', lw=2, label = r"$\lambda $" + f" = {lambdas[i]}")

    ax.set_xlabel("Iterations")
    ax.set_ylabel("Loss")
    ax.legend(title="lambda",
                       bbox_to_anchor=(1.06, 0.3), loc="center left",  frameon=False)

    plt.show()

# %%
plot_trainings_losses(losses_list, lambdas=[0.01, 0.1, 1, 5])

# %% [markdown]
# ## Optimal values for gamma
# lamda = 0.1

# %%
losses_list =[]
gammas=[0.01, 0.1, 1, 5]
for gamma  in gammas:
    _, _ ,losses_train, _, _, _= als_100k_data.alternating_least_square(als_100k_data.data_by_user_train, als_100k_data.data_by_movie_train, lambd=0.1, gamma=gamma, epochs = 5)
    losses_list.append(losses_train)
# Out:
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.87s/epoch, test_rmse=1.01]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.86s/epoch, test_rmse=0.934]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.85s/epoch, test_rmse=0.972]
# Training: 100%|██████████| 5/5 [00:09<00:00,  1.85s/epoch, test_rmse=1.43]

# %%
plot_trainings_losses(losses_list, lambdas=gammas)

# %% [markdown]
# ## Plot RMSEs on training and test sets

# %%
als_100k_data.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", title="RMSE evolution through iterations")

# %% [markdown]
# ## Identify the latents factor dimension

# %%
import numpy as np
import matplotlib.pyplot as plt

latents_dimensions = np.arange(1,80) 

data_dir = '../data/ml-latest-small/ratings.csv'
best_test_rmses = []
for latent_dimension in latents_dimensions :

    als_100k_data = AlternatingLeastSquare(data_dir, embedding_dim=latent_dimension)

    als_100k_data.train_test_split()
    _, _, _, _, _, rmses_test= als_100k_data.alternating_least_square(als_100k_data.data_by_user_train, als_100k_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 100)
    best_test_rmses.append(min(rmses_test))



plt.plot(latents_dimensions, best_test_rmses)
plt.xlabel("Latents dimensions")
plt.ylabel("Test Rmses")
# Out:
# Training: 100%|██████████| 100/100 [01:06<00:00,  1.51epoch/s, test_rmse=1.59]
# Training: 100%|██████████| 100/100 [00:58<00:00,  1.71epoch/s, test_rmse=1.59]
# Training: 100%|██████████| 100/100 [00:58<00:00,  1.70epoch/s, test_rmse=1.83]
# Training: 100%|██████████| 100/100 [00:56<00:00,  1.76epoch/s, test_rmse=1.95]
# Training: 100%|██████████| 100/100 [00:57<00:00,  1.74epoch/s, test_rmse=1.96]
# Training: 100%|██████████| 100/100 [00:57<00:00,  1.75epoch/s, test_rmse=2.15]
# Training: 100%|██████████| 100/100 [00:58<00:00,  1.72epoch/s, test_rmse=2.09]
# Training: 100%|██████████| 100/100 [00:58<00:00,  1.70epoch/s, test_rmse=2.08]
# Training: 100%|██████████| 100/100 [00:58<00:00,  1.70epoch/s, test_rmse=2.07]
# Training: 100%|██████████| 100/100 [00:59<00:00,  1.67epoch/s, test_rmse=2.09]
# Training: 100%|██████████| 100/100 [01:00<00:00,  1.66epoch/s, test_rmse=2.19]
# Training: 100%|██████████| 100/100 [01:01<00:00,  1.62epoch/s, test_rmse=2.15]
# Training: 100%|██████████| 100/100 [01:02<00:00,  1.61epoch/s, test_rmse=2.07]
# Training: 100%|██████████| 100/100 [01:02<00:00,  1.59epoch/s, test_rmse=2.06]
# Training: 100%|██████████| 100/100 [01:03<00:00,  1.56epoch/s, test_rmse=2.01]
# Training: 100%|██████████| 100/100 [01:03<00:00,  1.57epoch/s, test_rmse=1.93]
# Training: 100%|██████████| 100/100 [01:05<00:00,  1.53epoch/s, test_rmse=1.89]
# Training: 100%|██████████| 100/100 [01:05<00:00,  1.53epoch/s, test_rmse=1.88]
# Training: 100%|██████████| 100/100 [01:06<00:00,  1.51epoch/s, test_rmse=1.8]
# Training: 100%|██████████| 100/100 [01:06<00:00,  1.49epoch/s, test_rmse=1.77]
# Training: 100%|██████████| 100/100 [01:08<00:00,  1.47epoch/s, test_rmse=1.74]
# Training: 100%|██████████| 100/100 [01:08<00:00,  1.46epoch/s, test_rmse=1.73]
# Training: 100%|██████████| 100/100 [01:11<00:00,  1.41epoch/s, test_rmse=1.62]
# Training: 100%|██████████| 100/100 [01:10<00:00,  1.42epoch/s, test_rmse=1.55]
# Training: 100%|██████████| 100/100 [01:12<00:00,  1.39epoch/s, test_rmse=1.53]
# Training: 100%|██████████| 100/100 [01:12<00:00,  1.37epoch/s, test_rmse=1.51]
# Training: 100%|██████████| 100/100 [01:14<00:00,  1.34epoch/s, test_rmse=1.46]
# Training: 100%|██████████| 100/100 [01:14<00:00,  1.34epoch/s, test_rmse=1.42]
# Training: 100%|██████████| 100/100 [01:15<00:00,  1.33epoch/s, test_rmse=1.39]
# Training: 100%|██████████| 100/100 [01:15<00:00,  1.32epoch/s, test_rmse=1.35]
# Training: 100%|██████████| 100/100 [01:18<00:00,  1.28epoch/s, test_rmse=1.3]
# Training: 100%|██████████| 100/100 [01:18<00:00,  1.28epoch/s, test_rmse=1.29]
# Training: 100%|██████████| 100/100 [01:20<00:00,  1.24epoch/s, test_rmse=1.26]
# Training: 100%|██████████| 100/100 [01:19<00:00,  1.25epoch/s, test_rmse=1.23]
# Training: 100%|██████████| 100/100 [01:22<00:00,  1.21epoch/s, test_rmse=1.22]
# Training: 100%|██████████| 100/100 [01:22<00:00,  1.21epoch/s, test_rmse=1.2]
# Training: 100%|██████████| 100/100 [01:25<00:00,  1.17epoch/s, test_rmse=1.19]
# Training: 100%|██████████| 100/100 [01:26<00:00,  1.16epoch/s, test_rmse=1.19]
# Training: 100%|██████████| 100/100 [01:31<00:00,  1.09epoch/s, test_rmse=1.14]
# Training: 100%|██████████| 100/100 [01:29<00:00,  1.12epoch/s, test_rmse=1.14]
# Training: 100%|██████████| 100/100 [01:30<00:00,  1.11epoch/s, test_rmse=1.13]
# Training: 100%|██████████| 100/100 [01:32<00:00,  1.08epoch/s, test_rmse=1.13]
# Training: 100%|██████████| 100/100 [01:34<00:00,  1.06epoch/s, test_rmse=1.11]
# Training: 100%|██████████| 100/100 [01:34<00:00,  1.05epoch/s, test_rmse=1.1]
# Training: 100%|██████████| 100/100 [01:36<00:00,  1.04epoch/s, test_rmse=1.09]
# Training: 100%|██████████| 100/100 [01:40<00:00,  1.00s/epoch, test_rmse=1.09]
# Training: 100%|██████████| 100/100 [01:42<00:00,  1.02s/epoch, test_rmse=1.07]
# Training: 100%|██████████| 100/100 [01:42<00:00,  1.03s/epoch, test_rmse=1.08]
# Training: 100%|██████████| 100/100 [01:45<00:00,  1.06s/epoch, test_rmse=1.06]
# Training: 100%|██████████| 100/100 [01:48<00:00,  1.09s/epoch, test_rmse=1.07]
# Training: 100%|██████████| 100/100 [01:52<00:00,  1.12s/epoch, test_rmse=1.06]
# Training: 100%|██████████| 100/100 [01:53<00:00,  1.14s/epoch, test_rmse=1.05]
# Training: 100%|██████████| 100/100 [01:54<00:00,  1.15s/epoch, test_rmse=1.05]
# Training: 100%|██████████| 100/100 [01:57<00:00,  1.17s/epoch, test_rmse=1.05]
# Training: 100%|██████████| 100/100 [02:00<00:00,  1.21s/epoch, test_rmse=1.04]
# Training: 100%|██████████| 100/100 [01:59<00:00,  1.20s/epoch, test_rmse=1.03]
# Training: 100%|██████████| 100/100 [02:02<00:00,  1.23s/epoch, test_rmse=1.03]
# Training: 100%|██████████| 100/100 [02:06<00:00,  1.26s/epoch, test_rmse=1.03]
# Training: 100%|██████████| 100/100 [02:09<00:00,  1.30s/epoch, test_rmse=1.02]
# Training: 100%|██████████| 100/100 [02:11<00:00,  1.32s/epoch, test_rmse=1.02]
# Training: 100%|██████████| 100/100 [02:13<00:00,  1.33s/epoch, test_rmse=1.02]
# Training: 100%|██████████| 100/100 [02:15<00:00,  1.35s/epoch, test_rmse=1.01]
# Training: 100%|██████████| 100/100 [02:19<00:00,  1.40s/epoch, test_rmse=1.01]
# Training: 100%|██████████| 100/100 [02:16<00:00,  1.37s/epoch, test_rmse=1.01]
# Training: 100%|██████████| 100/100 [02:19<00:00,  1.40s/epoch, test_rmse=1]
# Training: 100%|██████████| 100/100 [02:19<00:00,  1.40s/epoch, test_rmse=0.999]
# Training: 100%|██████████| 100/100 [02:27<00:00,  1.48s/epoch, test_rmse=0.995]
# Training: 100%|██████████| 100/100 [02:26<00:00,  1.46s/epoch, test_rmse=0.991]
# Training: 100%|██████████| 100/100 [02:29<00:00,  1.49s/epoch, test_rmse=0.983]
# Training: 100%|██████████| 100/100 [02:28<00:00,  1.49s/epoch, test_rmse=0.985]
# Training: 100%|██████████| 100/100 [02:35<00:00,  1.56s/epoch, test_rmse=0.984]
# Training: 100%|██████████| 100/100 [02:33<00:00,  1.54s/epoch, test_rmse=0.986]
# Training: 100%|██████████| 100/100 [02:41<00:00,  1.61s/epoch, test_rmse=0.977]
# Training: 100%|██████████| 100/100 [02:42<00:00,  1.62s/epoch, test_rmse=0.975]
# Training: 100%|██████████| 100/100 [02:46<00:00,  1.66s/epoch, test_rmse=0.975]
# Training: 100%|██████████| 100/100 [02:45<00:00,  1.65s/epoch, test_rmse=0.972]
# Training: 100%|██████████| 100/100 [02:55<00:00,  1.76s/epoch, test_rmse=0.975]
# Training: 100%|██████████| 100/100 [02:54<00:00,  1.74s/epoch, test_rmse=0.975]
# Training: 100%|██████████| 100/100 [02:59<00:00,  1.80s/epoch, test_rmse=0.964]
# Text(0, 0.5, 'Test Rmses')

# %% [markdown]
# ## Recommendations for userId= 100

# %%
movies_dir = "../data/ml-latest-small/movies.csv"
als_100k_data.recommendation_for_user(movies_dir, user_id=13)
# Out:
# User 13 may also like:['Fargo (1996)', 'Monty Python and the Holy Grail (1975)', 'Indiana Jones and the Last Crusade (1989)', 'Men in Black (a.k.a. MIB) (1997)', 'Goonies, The (1985)']

# %% [markdown]
# # Results on the 25K movilens datasets

# %% [markdown]
# # create object and get the data

# %%
data_dir = '../data/ml-25m/ratings.csv'
als_25m_data = AlternatingLeastSquare(data_dir, embedding_dim=5)
als_25m_data.data_indexing()

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Power law

# %%
als_25m_data.plot_power_law("power_law_25m")

# %% [markdown]
# ### Ratings distribution

# %%
als_25m_data.plot_average_rating_hist("ratings_25m")

# %% [markdown]
# ## Train test split

# %%
als_25m_data.train_test_split()

# %% [markdown]
# ## Run the model: biases + embeddings

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= als_25m_data.alternating_least_square(als_25m_data.data_by_user_train, als_25m_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 20)
# Out:
# Training:   0%|          | 0/20 [00:00<?, ?epoch/s]Training: 100%|██████████| 20/20 [43:27<00:00, 130.38s/epoch, test_rmse=0.855]

# %% [markdown]
# ## Plot losses on training and test sets

# %%
als_25m_data.line_plot(losses, losses_test, xaxis = "Iterations", yaxis = "Loss", fig_name="b+e_25m_loss_train_test")

# %% [markdown]
# ## Plot RMSEs on training and test sets

# %%
als_25m_data.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE",  fig_name="b+e_25m_rmse_train_test")

# %% [markdown]
# ##  Training only loss

# %%
als_25m_data.plot_training_loss_only(losses,xaxis = "Iterations" , yaxis= "Loss", fig_name="b+e_only_125m_loss_train")

# %% [markdown]
# ## Recommendation for new user

# %%
als_25m_data.create_dummy_user(2116, 5)

movies_dir = '../data/ml-25m/movies.csv'
als_25m_data.recommendation_for_new_user(movies_dir, lambd=0.1, gamma=0.001)
# Out:
# You may also like:['Buzzard (2015)', 'The Green Elephant (1999)', 'Fateful Findings (2013)', 'My Mistress (2014)', 'Hellraiser: Judgment (2018)', 'Antares (2004)', 'Muck (2015)', 'Nomad (Köshpendiler) (2005)', "Monty Python's Fliegender Zirkus (1971)", 'Adventures of Picasso, The (Picassos äventyr) (1978)']

# %% [markdown]
# # Describe and show how you chose the “best” number of latent dimensions for your model, and at which point you achieved diminishing returns

# %%
latents_dimensions = np.arange(1,15)

# %%
data_dir = '../data/ml-25m/ratings.csv'
best_test_rmses = []
for latent_dimension in latents_dimensions :

    als_100k_data = AlternatingLeastSquare(data_dir, embedding_dim=latent_dimension)

    als_100k_data.train_test_split()
    _, _, _, _, _, rmses_test= als_100k_data.alternating_least_square(als_100k_data .data_by_user_train, als_100k_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 100)
    best_test_rmses.append(min(rmses_test))
# Out:
# Training: 100%|██████████| 100/100 [3:43:56<00:00, 134.37s/epoch, test_rmse=0.838]
# Training: 100%|██████████| 100/100 [3:26:05<00:00, 123.65s/epoch, test_rmse=0.835]
# Training: 100%|██████████| 100/100 [3:28:57<00:00, 125.37s/epoch, test_rmse=0.836]
# Training: 100%|██████████| 100/100 [3:29:27<00:00, 125.68s/epoch, test_rmse=0.842]
# Training: 100%|██████████| 100/100 [3:31:40<00:00, 127.00s/epoch, test_rmse=0.851]
# Training:  95%|█████████▌| 95/100 [3:32:15<11:10, 134.05s/epoch, test_rmse=0.865]

# %% [markdown]
# ## Test RMSEs Evolution with number of latents dimensions

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(latents_dimensions, best_test_rmses)
plt.xlabel("Latents dimensions")
plt.ylabel("Test Rmses")
# Out:
# Text(0, 0.5, 'Test Rmses')

# %%
pd.DataFrame(als_25m_data.users_latents).to_csv("users_latents.csv")

# %%
pd.DataFrame(als_25m_data.items_latents).to_csv("items_latents.csv")

# %%
user_biases.tofile('users_biases.csv', sep = ',')

# %%
item_biases.tofile('item_biases.csv', sep = ',')
