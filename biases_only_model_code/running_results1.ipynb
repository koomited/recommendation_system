# %% [markdown]
# # Results on the 100K movilens datasets

# %%
from alternating_least_square import AlternatingLeastSquare

# %% [markdown]
# # create object and get the data

# %%
data_dir = '../data/ml-latest-small/ratings.csv'
als_100k_data = AlternatingLeastSquare(data_dir)

# %%
als_100k_data.data_indexing()

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Power law

# %%
als_100k_data.plot_power_law("power_law")

# %% [markdown]
# ### Ratings distribution

# %%
als_100k_data.plot_average_rating_hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 als_100k_data.plot_average_rating_hist()
#
# TypeError: AlternatingLeastSquare.plot_average_rating_hist() missing 1 required positional argument: 'fig_name'

# %% [markdown]
# ## Train test split

# %%
als_100k_data.train_test_split()

# %% [markdown]
# ## Run the model: biases + embeddings

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= als_100k_data.alternating_least_square(als_100k_data.data_by_user_train, als_100k_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 20)
# Out:
# Training: 100%|██████████| 20/20 [00:01<00:00, 14.53epoch/s, test_rmse=0.903]

# %% [markdown]
# ## Plot losses on training and test sets

# %%
als_100k_data.line_plot(losses, losses_test, xaxis = "Iterations", yaxis = "Loss", fig_name="b_only_100k_train_test_lost")

# %% [markdown]
# ## Plot RMSEs on training and test sets

# %%
als_100k_data.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", fig_name="b_only_100k_test_train_rmses")

# %% [markdown]
# ## Training Losss only

# %%
als_100k_data.plot_training_loss_only(losses,xaxis = "Iterations" , yaxis= "Loss", fig_name="b_only_100k_loss_train")

# %% [markdown]
# # Results on the 25K movilens datasets

# %% [markdown]
# # create object and get the data

# %%
data_dir = '../data/ml-25m/ratings.csv'
als_25m_data = AlternatingLeastSquare(data_dir)
als_25m_data.data_indexing()

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Power law

# %%
als_25m_data.plot_power_law("power_law_25m")

# %% [markdown]
# ### Ratings distribution

# %%
als_25m_data.plot_average_rating_hist("ratings_distribution_25m")

# %% [markdown]
# ## Train test split

# %%
als_25m_data.train_test_split()

# %% [markdown]
# ## Run the model: biases + embeddings

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= als_25m_data.alternating_least_square(als_25m_data.data_by_user_train, als_25m_data.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 10)
# Out:
# Training: 100%|██████████| 10/10 [03:18<00:00, 19.85s/epoch, test_rmse=0.863]

# %% [markdown]
# ## Plot losses on training and test sets

# %%
als_25m_data.line_plot(losses, losses_test, xaxis = "Iterations", yaxis = "Loss", fig_name="b_only_25m_train_test_loss")

# %% [markdown]
# ## Plot RMSEs on training and test sets

# %%
als_25m_data.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", fig_name="b_only_25m_train_test_rmse")

# %% [markdown]
# # Training loss,only

# %%
als_25m_data.plot_training_loss_only(losses,xaxis = "Iterations" , yaxis= "Loss", fig_name="b_only_25m_loss_train")
