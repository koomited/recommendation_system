# %%
from data_structure import dataIndexing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from data_structure import dataIndexing
#
# ModuleNotFoundError: No module named 'data_structure'

# %%
data_dir = '../data/ml-latest-small/ratings.csv'
data_indexed = dataIndexing(data_dir)

# %%
data_indexed.get_data()

# %%
data_indexed.plot_power_law()

# %%
data_indexed.plot_average_rating_hist()

# %%
data_indexed.train_test_split()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_indexed.train_test_split()
#
# NameError: name 'data_indexed' is not defined

# %% [markdown]
# ## User biases and items biases

# %% [markdown]
# The RMSEs are lower on the test set when I set the factors number to 2 very small at the beguinning but start increasing again.

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= data_indexed.alternating_least_square_biases(data_indexed.data_by_user_train, data_indexed.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 user_biases, item_biases ,losses, rmse, losses_test, rmses_test= data_indexed.alternating_least_square_biases(data_indexed.data_by_user_train, data_indexed.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 100)
#
# NameError: name 'data_indexed' is not defined

# %%
data_indexed.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", title="RMSE evolution through iterations")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_indexed.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", title="RMSE evolution through iterations")
#
# NameError: name 'data_indexed' is not defined

# %%
data_indexed.line_plot(losses, losses_test, xaxis = "Iterations", yaxis = "LOSS", title="LOSS evolution through iterations")

# %%
user_latent_best = data_indexed.users_latents

# %%
item_latents_best = data_indexed.items_latents

# %% [markdown]
# # Big data

# %%
data_dir25 = '../data/ml-25m/ratings.csv'
data_indexed25 = dataIndexing(data_dir25)

# %%
data_indexed25.train_test_split()

# %%
data_indexed25.get_data()

# %%
data_indexed25.plot_average_rating_hist()

# %%
data_indexed25.plot_power_law()

# %%
user_biases, item_biases ,losses, rmse, losses_test, rmses_test= data_indexed25.alternating_least_square_biases(data_indexed25.data_by_user_train, data_indexed25.data_by_movie_train, lambd=0.1, gamma=0.001, epochs = 10)
# Out:
# Training: 100%|██████████| 10/10 [05:09<00:00, 30.98s/epoch, test_rmse=0.862]

# %%
data_indexed.line_plot(rmse, rmses_test, xaxis = "Iterations", yaxis = "RMSE", title="RMSE evolution through iterations")

# %%
data_indexed25.line_plot(losses, losses_test, xaxis = "Iterations", yaxis = "LOSS", title="LOSS evolution through iterations")

# %%
import pandas as pd

# %%
path = '../data/ml-latest-small/ratings.csv'
df = pd.read_csv(path)

# %%
df.rating.values
# Out:
# array([4., 4., 4., ..., 5., 5., 3.])

# %%
df.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
from scipy.sparse import csr_matrix

# %%
len(df.rating.values)
# Out:
# 100836

# %%
len(df.userId.unique())*len(df.movieId.unique())
# Out:
# 5931640

# %%
ratings = csr_matrix(
    (df.rating.values, (df.userId.values, df.movieId.values)), 
    shape=(len(df.userId.unique())+1, len(df.movieId.unique())+183885+1)
).toarray()

# %%
ratings.shape
# Out:
# (611, 193610)

# %%
193609-9724
# Out:
# 183885

# %% [markdown]
# # Train test split

# %%
data_indexed.train_test_split()

# %%
len(data_indexed.data_by_user_train)
# Out:
# 610

# %%
len(data_indexed.data_by_user_test)
# Out:
# 610

# %%
def Remove(tuples):
    tuples = filter(None, tuples)
    return tuples
 
# Driver Code
tuples = [(), ('ram','15','8'), (), ('laxman', 'sita'), 
          ('krishna', 'akbar', '45'), ('',''),()]
print (Remove(tuples))

# %%
tuples = [(), ('ram', '15', '8'), (), ('laxman', 'sita'),
          ('krishna', 'akbar', '45'), ('', ''), ()]
 
tuples = list(filter(lambda x: len(x) > 0, tuples))
print(tuples)
# Out:
# [('ram', '15', '8'), ('laxman', 'sita'), ('krishna', 'akbar', '45'), ('', '')]

# %%
len(data_indexed.data_by_user_test)
# Out:
# 610

# %%
data_indexed.data_by_movie_train
# Out:
# [[(),
#   (),
#   (),
#   (15, 2.5),
#   (),
#   (17, 4.5),
#   (),
#   (18, 3.5),
#   (),
#   (19, 4.0),
#   (),
#   (21, 3.5),
#   (),
#   (27, 3.0),
#   (),
#   (),
#   (),
#   (33, 3.0),
#   (),
#   (),
#   (),
#   (44, 3.0),
#   (),
#   (),
#   (46, 5.0),
#   (),
#   (),
#   (),
#   (57, 5.0),
#   (),
#   (63, 5.0),
#   (),
#   (),
#   (),
#   (),
#   (),
#   (),
#   (76, 0.5),
#   (),
#   (),
#   (),
#   (),
#   (),
#   (90, 3.0),
#   (),
#   (),
#   (93, 3.0),
#   (),
#   (),
#   (98, 4.5),
#   (),
#   (103, 4.0),
#   (),
#   (107, 4.0),
#   (),
#   (),
#   (),
#   (121, 4.0),
#   (),
#   (124, 4.0),
#   (),
#   (130, 3.0),
#   (),
#   (),
#   (),
#   (),
#   (),
#   (),
#   (141, 4.0),
#   (),
#   (144, 3.5),
#   (),
#   (),
#   (151, 5.0),
#   (),
#   (153, 2.0),
#   (),
#   (155, 3.0),
#   (),
#   (156, 4.0),
#   (),
#   (159, 4.5),
#   (),
#   (160, 4.0),
#   (),
#   (),
#   (),
#   (167, 3.5),
#   (),
#   (169, 4.5),
#   (),
#   (171, 5.0),
#   (),
#   (),
#   (),
# ...

# %%
a = [(), (0,2)]
len(a[0])
# Out:
# 0

# %%
len(data_indexed.data_by_user_train[0])
# Out:
# 351

# %%
len(data_indexed.data_by_user_test[0])
# Out:
# 351

# %%
try:
    for (b, c) in a:
        print("Great")
except:
    continue
# Out:
#   Cell In [29], line 5
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop
